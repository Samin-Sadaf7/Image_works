# %% [markdown]
# <a href="https://colab.research.google.com/github/Samin-Sadaf7/Image_works/blob/main/DIP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
a = cv2.imread('/content/gdrive/MyDrive/lena.jpg')
a.shape
# Out:
# (266, 474, 3)

# %%
a
# Out:
# array([[[ 87, 121, 205],
#         [ 86, 120, 204],
#         [ 84, 118, 202],
#         ...,
#         [ 81, 100, 167],
#         [ 93, 112, 179],
#         [ 93, 112, 179]],
#
#        [[ 86, 120, 204],
#         [ 85, 119, 203],
#         [ 83, 117, 201],
#         ...,
#         [ 82, 101, 168],
#         [ 91, 110, 177],
#         [ 91, 110, 177]],
#
#        [[ 85, 119, 203],
#         [ 84, 118, 202],
#         [ 82, 116, 200],
#         ...,
#         [ 83, 102, 169],
#         [ 89, 108, 175],
#         [ 89, 108, 175]],
#
#        ...,
#
#        [[ 82, 111, 196],
#         [ 78, 107, 192],
#         [ 78, 107, 192],
#         ...,
#         [ 41,  43,  74],
#         [ 51,  53,  84],
#         [ 51,  53,  84]],
#
#        [[ 84, 113, 198],
#         [ 83, 112, 197],
#         [ 85, 114, 199],
#         ...,
#         [ 52,  53,  87],
#         [ 55,  57,  91],
#         [ 63,  65,  99]],
#
#        [[ 84, 113, 198],
#         [ 83, 112, 197],
#         [ 85, 114, 199],
#         ...,
#         [ 52,  53,  87],
#         [ 55,  57,  92],
#         [ 63,  65, 100]]], dtype=uint8)

# %%
resized_a = cv2.resize(a, (512, 512))

# %%
resized_a
# Out:
# array([[[ 87, 121, 205],
#         [ 86, 120, 204],
#         [ 84, 118, 202],
#         ...,
#         [ 83, 102, 169],
#         [ 93, 112, 179],
#         [ 93, 112, 179]],
#
#        [[ 87, 121, 204],
#         [ 86, 120, 204],
#         [ 84, 118, 202],
#         ...,
#         [ 83, 102, 169],
#         [ 92, 111, 178],
#         [ 92, 111, 178]],
#
#        [[ 86, 120, 204],
#         [ 85, 119, 203],
#         [ 83, 118, 201],
#         ...,
#         [ 83, 103, 170],
#         [ 91, 110, 177],
#         [ 91, 110, 177]],
#
#        ...,
#
#        [[ 84, 113, 198],
#         [ 83, 112, 197],
#         [ 85, 114, 198],
#         ...,
#         [ 52,  54,  88],
#         [ 56,  58,  92],
#         [ 63,  65,  99]],
#
#        [[ 84, 113, 198],
#         [ 83, 112, 197],
#         [ 84, 113, 198],
#         ...,
#         [ 52,  54,  88],
#         [ 56,  58,  92],
#         [ 63,  65, 100]],
#
#        [[ 84, 113, 198],
#         [ 83, 112, 197],
#         [ 85, 114, 198],
#         ...,
#         [ 52,  54,  88],
#         [ 56,  58,  93],
#         [ 63,  65, 100]]], dtype=uint8)

# %%
p = resized_a[100, 200]
p ##BGR Format
# Out:
# array([50, 42, 62], dtype=uint8)

# %%
for i in range(len(resized_a[100])):
    resized_a[100, i] = [255, 255, 0]
    resized_a[i, 100] = [30, 0, 255]

# %%
cv2_imshow(resized_a)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
resized_a.item(200,200,0), resized_a.item(200,200,1), resized_a.item(200,200,2)
# Out:
# (40, 33, 54)

# %%
resized_a.itemset((200,200,0), 255)

# %%
cv2_imshow(resized_a)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
randbin = np.random.choice([0,255], size=(100000,), p=[1./3,2./3])
flatnpArray =np.array(randbin,  dtype=np.uint8)
print(flatnpArray.shape)
binimg = flatnpArray.reshape(200,500)
cv2_imshow(binimg)
# Out:
# (100000,)
# <PIL.Image.Image image mode=L size=500x200>

# %%
choices = [ i for i in range(0,256)]
randbin = np.random.choice(choices, size=(3000000,))
flatnpArray =np.array(randbin,  dtype=np.uint8)
img = flatnpArray.reshape(1000, 1000, 3)
cv2_imshow(img)

# %%
bg = cv2.cvtColor(resized_a, cv2.COLOR_BGR2GRAY)
bg
# Out:
# array([[142, 141, 139, ..., 120, 130, 130],
#        [142, 141, 139, ..., 120, 129, 129],
#        [141, 140, 139, ..., 121, 128, 128],
#        ...,
#        [135, 134, 136, ...,  64,  68,  75],
#        [135, 134, 135, ...,  64,  68,  75],
#        [135, 134, 136, ...,  64,  68,  75]], dtype=uint8)

# %%
import numpy
import os

randomByteArray = bytearray(os.urandom(120000))
print(randomByteArray)
flatNumpyArray = numpy.array(randomByteArray)
print(flatNumpyArray)
# Out:
# bytearray(b'i\x16X\xb7:\xe6\xa8\x1e\x89\xe6\xcd\xf0\xdb#>\x95h\x16\xf8\xbd\xdf/\xa0\xe1\xa5\xe2\xdf\x16\xf6\xa9\x96e\x1a\x14\xfd\xd5\xc9\x14\x80\x8c\x8c\xd2\x8e\xe8$m}\xb5\x93\xff%7H\x10\x1f\xfb\xad(R;\xc42\xa4A;IaMR\x0b\x12\xa9\xe03\xf1"\xccOzl\xaf`\xe4\x16B\xa6\xb8L\xe8@\xf66\x03\x92k\x07\xff\xb4^\xc02cne\x872$\x8b=\xb7\xb6\x91\xa1I4\xd8\xf0\xa3^AlC\x04cH\xe8\xf9)U\x7f\xfc\x1c\xc5\x13}\xee\xc4\xbf\xd8\x98 \xfc\x06\x86\x9d\xff\x96\x00f4\x8d\xb3HP\x86\xf4CN0\xc2\xc5*;\x97\xa8L\xd0\x9bW\xfdP\xf2\x0f\x08F\xcd7es\x1bI\xfd"\x85\x11[cqcK\n\x9f\xdey;_\xcf\x1d_\xaf\xcf\xa3I\xf7?T-\xa0/\xce\xf0\xcaF|0\xa9\x90r\xe8*\x0e\xb7\xcd$\xdf\x03\xf2\xba\xdd\x18.\x01\xe0K\xe8Gl\xce\xdf\xfa\x81\xe0\xcc?\xb8\x89\xadg\x03]\xdd\x96\xfe\x87\xae"\x1aEl\x08\xb3\x04\xbf\xcc\xaf5\x8b\xad\xbdC\x187:\x83:\xbb\xe1&M\xf8\x0f\x0f\xe31\x10\xdafks^\xe3\xefP\r@\xf1\xab:C9]\xa4\x1f\x1er \x145\x8ac\xceE\x1bd\xc4\xd8\xe7;\xe6\x01C\xd8Y\xe2Th\x99T\x8bH\xab\x95\x86g*f\xfe\
\xd9o.&\x06\x1d\x85`(u1\x91\x0ege\x1b\xe9\x8a\xb6\x91\x1e\x05\x16{\xbd\xd8\xec\x04\x0e@\\\xd0D\x08\x14\\\xb4\xd6\ts\x96\x8d\xfd\xc0]\xa6g\x03\x079\xea<\x80\x07L\x1b\xb9\xc3$U\xbf#dp7\xb7\x80\xf6G\x93\xd7\xb9\x93X\xe3s\x07]\xc0\x84\xf6\x1c+\xc3\xf0\x80Z]\x8b\xab\xaeQ\x94\x85\xa7\xe1\x13\xfa\x0b`Jx\xd4%\xa9\xee\x0f\xfb\x19\xfa\xda\x1cI\x00\xe1OTh\xe4\x936\x140\x86KClv\r\x9c\x15\xbd\xca\x8b\x9c{\xb8F~(K1L\x98\xf8R\xa9\xe6\x91@\x84\x81&\xb1N2\xf2\x13\x07\xdf\x16z\xb7\xdf\x19eJ+&.\xbb\x87\xab\xc3\xdf\x8b\x04r\xc6\xb48\xb2\xeet\xc4\xdd\xc5w\x97S\x8fq\x17l*I\xca\xec\xa8\xcb\xa3sI\xe5\x14\x10h\'y\x06\x97\xeae\x82\xa2<\x0f!\x85/\x9b\x08\xe4:\xd5 \xe3jY\xe5/\xb5\xe8\xedl\xa8\xa5\xfe\xbb\x18\x98\x1eB\xe3/\xe8RQ\xbc^\xf4\x00\xff\xcb\xf6\x0f"\xff)VcA\xd2\x08\x86`\x13t\x0eH\xe4\xb4M\x94\xcdf\xc8\x99\xda\x05\xd5c6\x05\xe4j\xd5G\xfc\xc1$c\xd82`|\xdb\x89\xd5\x01+I\xf3\x00\x9c\xee\xc8h"\xadl\x9c\x80\xb4\xa2\x80\xca\xbd.DP\x10.\x13}\xd3"\x9f`-E\xed\x16\x1aR\xcd{\xa4\x7f\x9a\xb4\xd1\x81\xb8,\xe4u\xd5\xa6=\xda\x82\xf4o\xde\xb9\r\xf4`\xed_D\x84\xd8\xc6:\xad\x96\xac\x11\xc3G\xd0\x82\xd7\x18C\x82\xa1C\xac\xa5\xc9+\xa3\x8e\x07\x04\\\xd0$\xb9\xf7\x0ep:|n\x9b\x00\x8f\x99\xf4\x08\xe2\x0fM4\x85\xcc\xef\xd4&\xe6\x14\xabY\xaa5\xccV%\xc0T\xd6\x9a\xba\x1b&\xf1\'\xfc\x87\x9eW\xbe\n6\xe5\xaejI\x92\x86[(U\x90\xdd\x94\x86\x87<\x84\x92\x12\xb5=\xe12\xdc\xf2\x9b\xd0e\xee\xdf\x91\xd2\x92\x0c0\x8a\xf0\xd7\xf6$\xd8\xbd\xdb\xca\xb0\x ...
# [105  22  88 ... 192 246  49]

# %%
grayImage = flatNumpyArray.reshape(300, 400)
cv2.imwrite('RandomGray.png', grayImage)
# Out:
# True

# %%
colorImage = flatNumpyArray.reshape(100, 400, 3)
cv2.imwrite('colorImage.png', colorImage)
# Out:
# True

# %%
cv2_imshow(colorImage)
# Out:
# <PIL.Image.Image image mode=RGB size=400x100>

# %%
cv2_imshow(grayImage)
# Out:
# <PIL.Image.Image image mode=L size=400x300>
