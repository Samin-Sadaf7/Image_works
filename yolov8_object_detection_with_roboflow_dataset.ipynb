# %% [markdown]
# <a href="https://colab.research.google.com/github/Samin-Sadaf7/Image_works/blob/main/yolov8_object_detection_with_roboflow_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # YOLOv8 Object Detection on a Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## ⚠️ Disclaimer
#
# YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **03.01.2024** with version **YOLOv8.0.196**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on how to train YOLOv8 Object Detection, concurrently.
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Wed Sep 11 05:47:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **03.01.2024** with version **YOLOv8.0.196**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %% [markdown]
# ## Training on Traffic Sign Detection Dataset

# %%
# %cd /content/
# Out:
# /content

# %%
import os
import shutil

# Define paths
xml_folder = 'label'
img_folder = 'images'

# Create folders if they don't exist
os.makedirs(xml_folder, exist_ok=True)
os.makedirs(img_folder, exist_ok=True)

# Get a list of all XML files in the current directory
xml_files = [file for file in os.listdir() if file.endswith('.xml')]

# Get a list of all PNG files in the current directory
png_files = [file for file in os.listdir() if file.endswith('.png')]

# Move XML files to the 'label' folder
for xml_file in xml_files:
    shutil.move(xml_file, os.path.join(xml_folder, xml_file))

# Move PNG files to the 'images' folder
for png_file in png_files:
    shutil.move(png_file, os.path.join(img_folder, png_file))

# %%
import yaml

# Define the data
data = {
    'nc': 15,
    'train': '/content/drive/MyDrive/Dataset- -Conference/train/',
    'val': '/content/drive/MyDrive/Dataset- -Conference/val/',
    'names': [
        'SpeedLimit60kmh',
        'School',
        'PEDESTRIANCROSSING',
        'SharpBendToTheLeft',
        'UTurn',
        'speedlimit80kmh',
        'NoOvertaking',
        'SharpBendToTheRight',
        'SideRoadLeft',
        'SideRoadRight',
        'speedlimit40kmh',
        'NarrowBridge',
        'RoadHump',
        'nouseofhorn',
        'Crossroads'
    ]
}

# Write the data to conference.yml
with open('conference.yml', 'w') as yaml_file:
    yaml.dump(data, yaml_file)

# %%
import xml.etree.ElementTree as ET
import os

# Class names
class_names =[
        'SpeedLimit60kmh',
        'School',
        'PEDESTRIANCROSSING',
        'SharpBendToTheLeft',
        'UTurn',
        'speedlimit80kmh',
        'NoOvertaking',
        'SharpBendToTheRight',
        'SideRoadLeft',
        'SideRoadRight',
        'speedlimit40kmh',
        'NarrowBridge',
        'RoadHump',
        'nouseofhorn',
        'Crossroads'
    ]

# Create class dictionary
class_dict = {class_name: i for i, class_name in enumerate(class_names)}

def xml_to_yolo(xml_file, class_dict):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    image_size = root.find('size')
    width = float(image_size.find('width').text)
    height = float(image_size.find('height').text)

    yolo_annotations = []
    for obj in root.findall('object'):
        class_name = obj.find('name').text.strip().replace(' ', '').replace('/', '')  # Remove spaces and '/'
        class_id = class_dict.get(class_name)
        if class_id is None:
            print(f"Warning: Class '{class_name}' not found in class dictionary.")
            continue

        bbox = obj.find('bndbox')
        xmin = float(bbox.find('xmin').text)
        ymin = float(bbox.find('ymin').text)
        xmax = float(bbox.find('xmax').text)
        ymax = float(bbox.find('ymax').text)

        # Calculate normalized coordinates
        x_center = (xmin + xmax) / (2 * width)
        y_center = (ymin + ymax) / (2 * height)
        bbox_width = (xmax - xmin) / width
        bbox_height = (ymax - ymin) / height

        yolo_annotations.append(f"{class_id} {x_center} {y_center} {bbox_width} {bbox_height}")

    return yolo_annotations


def convert_annotations(xml_dir, output_dir, class_dict):
    os.makedirs(output_dir, exist_ok=True)

    for xml_file in os.listdir(xml_dir):
        if xml_file.endswith('.xml'):
            img_id = os.path.splitext(xml_file)[0]
            yolo_annotations = xml_to_yolo(os.path.join(xml_dir, xml_file), class_dict)
            with open(os.path.join(output_dir, f"{img_id}.txt"), 'w') as f:
                f.write('\n'.join(yolo_annotations))

# Paths
xml_dir = '/content/drive/MyDrive/Dataset- -Conference/train/labels1'
output_dir = '/content/drive/MyDrive/Dataset- -Conference/train/labels'

# Convert annotations
convert_annotations(xml_dir, output_dir, class_dict)

# %%
# train label Paths
xml_dir = '/content/drive/MyDrive/Dataset- -Conference/train/labels1'
output_dir = '/content/drive/MyDrive/Dataset- -Conference/train/labels'

# Convert annotations
convert_annotations(xml_dir, output_dir, class_dict)

# %%
# valid test Paths
xml_dir = '/content/drive/MyDrive/Dataset- -Conference/val/labels1'
output_dir = '/content/drive/MyDrive/Dataset- -Conference/val/labels'

# Convert annotations
convert_annotations(xml_dir, output_dir, class_dict)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/drive/MyDrive/Dataset- -Conference/yolov8/p3/runs/detect/train2/weights/last.pt")

# %%
# Train the model
results = model.train(data='/content/drive/MyDrive/Dataset- -Conference/dataset.yaml', epochs=500)

# %%
# Train the model
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.91 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=/content/drive/MyDrive/Dataset- -Conference/yolov8/p3/runs/detect/train2/weights/last.pt, data=/content/drive/MyDrive/Dataset- -Conference/dataset.yaml, epochs=500, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    754237  ultralytics.nn.modules.head.Detect           [15, [64, 128, 256]]
# Model summary: 225 layers, 3013773 parameters, 3013757 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Dataset- -Conference/train/labels.cache... 2096 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2096/2096 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/albumentations/core/composition.py:161: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Dataset- -Conference/valid/labels.cache... 256 images, 0 backgrounds, 0 corrupt: 100%|██████████| 256/256 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training from /content/drive/MyDrive/Dataset- -Conference/yolov8/p3/runs/detect/train2/weights/last.pt from epoch 2 to 500 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/500      2.25G      0.874     0.5131     0.8642         27        640: 100%|██████████| 131/131 [02:03<00:00,  1.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:09<00:00,  1.15s/it]
#                    all        256        277     0.0658     0.0667     0.0803     0.0573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/500       2.3G      1.025     0.6447     0.8949         35        640: 100%|██████████| 131/131 [01:57<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:10<00:00,  1.26s/it]
#                    all        256        277      0.265     0.0444     0.0782     0.0527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/500       2.3G      1.117     0.8098     0.9194         26        640: 100%|██████████| 131/131 [01:54<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:05<00:00,  1.42it/s]
#                    all        256        277     0.0657     0.0435     0.0525     0.0361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/500       2.3G      1.141     0.8768     0.9263         42        640: 100%|██████████| 131/131 [01:57<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:10<00:00,  1.36s/it]
#                    all        256        277      0.247     0.0591     0.0775     0.0545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/500       2.3G      1.131     0.8656     0.9219         24        640: 100%|██████████| 131/131 [01:54<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:06<00:00,  1.27it/s]
#                    all        256        277      0.215     0.0786     0.0848     0.0569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/500       2.3G       1.12     0.8778     0.9211         20        640: 100%|██████████| 131/131 [01:54<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:10<00:00,  1.29s/it]
#                    all        256        277     0.0928     0.0735     0.0268     0.0176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/500       2.3G      1.117      0.839     0.9192         34        640: 100%|██████████| 131/131 [01:59<00:00,  1.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:07<00:00,  1.06it/s]
#                    all        256        277     0.0514     0.0843       0.07     0.0435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/500       2.3G      1.089     0.8185     0.9256         30        640: 100%|██████████| 131/131 [01:55<00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:06<00:00,  1.17it/s]
#                    all        256        277     0.0598     0.0572     0.0792     0.0546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/500       2.3G        1.1     0.8241      0.917         40        640: 100%|██████████| 131/131 [01:57<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:10<00:00,  1.34s/it]
#                    all        256        277      0.266     0.0556     0.0689     0.0532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/500       2.3G      1.101     0.7827     0.9278         28        640: 100%|██████████| 131/131 [01:53<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:06<00:00,  1.19it/s]
#                    all        256        277      0.113     0.0556      0.053     0.0377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/500       2.3G      1.076     0.7378     0.9036         46        640:  59%|█████▉    | 77/131 [01:07<00:47,  1.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-083a4b22cfd6> in <cell line: 2>()
#       1 # Train the model
# ----> 2 results = model.train(resume=True)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     339             self.model = self.trainer.model
#     340         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 341         self.trainer.train()
#     342         # Update model and cfg after training
#     343         if RANK in (-1, 0):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in train(self)
#     189
#     190         else:
# --> 191             self._do_train(world_size)
#     192
#     193     def _setup_ddp(self, world_size):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     323             self.tloss = None
#     324             self.optimizer.zero_grad()
# --> 325             for i, batch in pbar:
#     326                 self.run_callbacks('on_train_batch_start')
#     327                 # Warmup
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/data/build.py in __iter__(self)
#      40         """Creates a sampler that repeats indefinitely."""
#      41         for _ in range(len(self)):
# ---> 42             yield next(self.iterator)
#      43
#      44     def reset(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1325
#    1326             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1327             idx, data = self._get_data()
#    1328             self._tasks_outstanding -= 1
#    1329             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1281         elif self._pin_memory:
#    1282             while self._pin_memory_thread.is_alive():
# -> 1283                 success, data = self._try_get_data()
#    1284                 if success:
#    1285                     return data
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1129         #   (bool: whether successfully get data, any: data if successful else None)
#    1130         try:
# -> 1131             data = self._data_queue.get(timeout=timeout)
#    1132             return (True, data)
#    1133         except Exception as e:
#
# /usr/lib/python3.10/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     322             else:
#     323                 if timeout > 0:
# --> 324                     gotit = waiter.acquire(True, timeout)
#     325                 else:
#     326                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Define paths
import shutil
source_folder = '/content/runs/detect/train3'
destination_folder = '/content/drive/MyDrive/Dataset- -Conference/yolov8/p3/runs/detect/train3'  # Path to the destination folder
# Copy the folder and its contents to the destination
shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/drive/MyDrive/Dataset- -Conference/yolov8/p3/runs/detect/train3'

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Now you can run your YOLO command
from ultralytics import YOLO
# !yolo task=detect mode=val model='/content/runs/detect/train/weights/best.pt' data=/content/drive/MyDrive/BD_Road_Sign_Dataset/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3011108 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/BD_Road_Sign_Dataset/valid/labels.cache... 46 images, 0 backgrounds, 0 corrupt: 100% 46/46 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:03<00:00,  1.18s/it]
#                    all         46         49      0.873      0.894      0.941      0.879
#               Bus Stop         46          1      0.862          1      0.995      0.995
#       Crossroads Ahead         46          2      0.985          1      0.995      0.995
#                Go Left         46          2      0.915          1      0.995      0.947
#                Go Slow         46          1      0.862          1      0.995      0.895
#         Hospital Ahead         46          2      0.967        0.5      0.523      0.419
#              Left Turn         46          2      0.899          1      0.995      0.946
#    Narrow Bridge Ahead         46          1     0.0817      0.163      0.497      0.497
# Narrow Road on Left Ahead         46          2      0.903          1      0.995      0.995
#               No Horns         46          1      0.895          1      0.995      0.995
#          No-Overtaking         46          3      0.928          1      0.995      0.995
#    Rail Crossing Ahead         46          1      0.862          1      0.995      0.895
#             Right Turn         46          4      0.935          1      0.995      0.946
#           Road On Left         46          1       0.82          1      0.995      0.895
#          Road On Right         46          2          1      0.608      0.995      0.895
#           School Ahead         46          6      0.955          1      0.995      0.914
#    Speed Breaker Ahead         46          2       0.84        0.5      0.828      0.617
#      Speed Limit 20kmh         46          1      0.874          1      0.995      0.995
#      Speed Limit 40kmh         46          7       0.98          1      0.995      0.966
#      Speed Limit 60kmh         46          3      0.938          1      0.995      0.995
#                   Stop         46          1      0.865          1      0.995      0.796
#  Street Crossing Ahead         46          4      0.972          1      0.995      0.874
# Speed: 4.5ms preprocess, 28.1ms inference, 0.0ms loss, 20.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# Define paths
import shutil
source_folder = '/content/runs/'
destination_folder = '/content/drive/MyDrive/BD_Road_Sign_Dataset/yolov8/final'  # Path to the destination folder
# Copy the folder and its contents to the destination
shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/drive/MyDrive/BD_Road_Sign_Dataset/yolov8/final'

# %%
# Run on test set for prediction
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/Dataset- -Conference/test/images'
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0029_0.png: 640x384 1 School, 55.2ms
# image 2/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0029_13.png: 640x384 1 School, 7.6ms
# image 3/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0029_17.png: 640x384 1 School, 8.3ms
# image 4/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0029_9.png: 640x384 1 School, 7.5ms
# image 5/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_1370.png: 384x640 1 Crossroads, 37.1ms
# image 6/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_1380.png: 384x640 1 Crossroads, 7.2ms
# image 7/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_1390.png: 384x640 1 Crossroads, 15.0ms
# image 8/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_1400.png: 384x640 1 Side Road Right, 1 Crossroads, 7.0ms
# image 9/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_1410.png: 384x640 1 Crossroads, 7.3ms
# image 10/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_1420.png: 384x640 1 Crossroads, 10.0ms
# image 11/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_1430.png: 384x640 1 Crossroads, 7.5ms
# image 12/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_240.png: 384x640 1 Side Road Right, 7.3ms
# image 13/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0043_250.png: 384x640 1 Crossroads, 6.8ms
# image 14/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0045_230.png: 384x640 1 School, 7.0ms
# image 15/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0045_240.png: 384x640 1 Sharp Bend To The Left, 7.0ms
# image 16/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0045_250.png: 384x640 1 Sharp Bend To The Left, 7.2ms
# image 17/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_1790.png: 384x640 1 No Overtaking, 7.3ms
# image 18/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_1800.png: 384x640 1 No Overtaking, 6.9ms
# image 19/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_1810.png: 384x640 1 No Overtaking, 12.8ms
# image 20/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_1820.png: 384x640 1 No Overtaking, 13.1ms
# image 21/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_1830.png: 384x640 1 No Overtaking, 12.5ms
# image 22/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2170.png: 384x640 1 School, 9.9ms
# image 23/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2180.png: 384x640 1 School, 10.1ms
# image 24/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2190.png: 384x640 1 School, 9.4ms
# image 25/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2200.png: 384x640 1 School, 1 Side Road Right, 9.3ms
# image 26/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2210.png: 384x640 1 School, 1 Side Road Right, 8.4ms
# image 27/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2670.png: 384x640 1 speed limit 40 km/h, 8.3ms
# image 28/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2680.png: 384x640 1 speed limit 40 km/h, 8.3ms
# image 29/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_2690.png: 384x640 1 speed limit 40 km/h, 10.7ms
# image 30/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_690.png: 384x640 1 speed limit 40 km/h, 11.9ms
# image 31/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_700.png: 384x640 1 speed limit 40 km/h, 11.8ms
# image 32/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_710.png: 384x640 (no detections), 12.4ms
# image 33/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_740.png: 384x640 1 speed limit 40 km/h, 8.8ms
# image 34/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_760.png: 384x640 1 speed limit 40 km/h, 14.0ms
# image 35/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_770.png: 384x640 1 speed limit 40 km/h, 10.0ms
# image 36/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_780.png: 384x640 1 speed limit 40 km/h, 15.0ms
# image 37/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_800.png: 384x640 1 speed limit 40 km/h, 9.8ms
# image 38/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_810.png: 384x640 1 speed limit 40 km/h, 9.8ms
# image 39/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_820.png: 384x640 1 speed limit 40 km/h, 11.1ms
# image 40/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_830.png: 384x640 1 speed limit 40 km/h, 23.5ms
# image 41/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_840.png: 384x640 1 speed limit 40 km/h, 16.7ms
# image 42/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_850.png: 384x640 1 speed limit 40 km/h, 10.6ms
# image 43/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0046_860.png: 384x640 1 speed limit 40 km/h, 11.8ms
# image 44/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_3630.png: 384x640 1 Road Hump, 11.9ms
# image 45/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_3640.png: 384x640 1 Road Hump, 12.7ms
# image 46/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_3650.png: 384x640 1 Road Hump, 14.9ms
# image 47/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_3980.png: 384x640 1 Sharp Bend To The Left, 11.7ms
# image 48/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_3990.png: 384x640 (no detections), 9.1ms
# image 49/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_4000.png: 384x640 1 Side Road Left, 7.0ms
# image 50/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_4010.png: 384x640 1 School, 7.0ms
# image 51/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_4020.png: 384x640 1 School, 7.0ms
# image 52/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_4030.png: 384x640 1 School, 10.2ms
# image 53/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_4040.png: 384x640 1 School, 9.1ms
# image 54/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_530.png: 384x640 1 Sharp Bend To The Left, 9.2ms
# image 55/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_540.png: 384x640 1 Sharp Bend To The Left, 10.5ms
# image 56/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0048_550.png: 384x640 1 Sharp Bend To The Left, 10.9ms
# image 57/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0049_10050.png: 384x640 1 Side Road Left, 10.4ms
# image 58/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0049_10060.png: 384x640 (no detections), 8.4ms
# image 59/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0049_10070.png: 384x640 1 Side Road Left, 8.4ms
# image 60/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0049_10080.png: 384x640 1 Side Road Left, 8.4ms
# image 61/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V
662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_5200.png: 384x640 1 speed limit 40 km/h, 1 Sharp Bend To The Left, 10.9ms
# image 102/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_5210.png: 384x640 1 speed limit 40 km/h, 1 Sharp Bend To The Left, 6.4ms
# image 103/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_5220.png: 384x640 1 speed limit 40 km/h, 1 Sharp Bend To The Left, 6.7ms
# image 104/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_5230.png: 384x640 1 speed limit 40 km/h, 1 Sharp Bend To The Left, 12.2ms
# image 105/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_5760.png: 384x640 1 speed limit 40 km/h, 10.5ms
# image 106/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_5770.png: 384x640 1 speed limit 40 km/h, 8.7ms
# image 107/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_5790.png: 384x640 1 speed limit 40 km/h, 8.5ms
# image 108/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_6850.png: 384x640 (no detections), 9.1ms
# image 109/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0051_6860.png: 384x640 1 Sharp Bend To The Left, 8.5ms
# image 110/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0053_4300.png: 384x640 1 School, 10.9ms
# image 111/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0053_4310.png: 384x640 1 School, 11.8ms
# image 112/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0053_4320.png: 384x640 1 School, 11.7ms
# image 113/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0053_4330.png: 384x640 1 School, 12.8ms
# image 114/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0053_6310.png: 384x640 1 School, 12.2ms
# image 115/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0054_470.png: 384x640 (no detections), 10.6ms
# image 116/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0054_490.png: 384x640 1 speed limit 40 km/h, 9.9ms
# image 117/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0054_510.png: 384x640 1 speed limit 40 km/h, 9.6ms
# image 118/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0054_520.png: 384x640 1 speed limit 40 km/h, 11.9ms
# image 119/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_0.png: 640x384 (no detections), 10.8ms
# image 120/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_10.png: 640x384 (no detections), 11.6ms
# image 121/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_100.png: 640x384 1 Side Road Right, 13.3ms
# image 122/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_110.png: 640x384 1 School, 9.5ms
# image 123/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_120.png: 640x384 1 Side Road Right, 9.3ms
# image 124/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_140.png: 640x384 1 Side Road Right, 26.9ms
# image 125/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_150.png: 640x384 1 Side Road Right, 22.2ms
# image 126/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_160.png: 640x384 1 Side Road Right, 9.8ms
# image 127/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_170.png: 640x384 1 Side Road Right, 9.9ms
# image 128/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_20.png: 640x384 1 PEDESTRIAN CROSSING, 9.4ms
# image 129/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_30.png: 640x384 1 PEDESTRIAN CROSSING, 9.9ms
# image 130/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_40.png: 640x384 1 Side Road Right, 9.8ms
# image 131/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_60.png: 640x384 (no detections), 9.5ms
# image 132/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_80.png: 640x384 1 School, 10.7ms
# image 133/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0056_90.png: 640x384 1 Side Road Right, 14.2ms
# image 134/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_130.png: 640x384 1 Narrow Bridge, 13.6ms
# image 135/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_140.png: 640x384 1 Narrow Bridge, 11.8ms
# image 136/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_150.png: 640x384 1 Narrow Bridge, 11.6ms
# image 137/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_170.png: 640x384 1 Narrow Bridge, 11.2ms
# image 138/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_180.png: 640x384 1 Side Road Right, 1 Narrow Bridge, 11.0ms
# image 139/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_190.png: 640x384 1 Narrow Bridge, 11.3ms
# image 140/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_200.png: 640x384 1 Narrow Bridge, 19.4ms
# image 141/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_210.png: 640x384 1 Narrow Bridge, 7.1ms
# image 142/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_220.png: 640x384 1 Narrow Bridge, 7.4ms
# image 143/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_230.png: 640x384 1 Narrow Bridge, 7.1ms
# image 144/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0057_240.png: 640x384 1 Sharp Bend To The Left, 6.6ms
# image 145/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_140.png: 640x384 1 School, 7.7ms
# image 146/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_170.png: 640x384 1 School, 1 Sharp Bend To The Left, 6.5ms
# image 147/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_190.png: 640x384 1 School, 1 Sharp Bend To The Left, 6.6ms
# image 148/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_210.png: 640x384 1 School, 1 Sharp Bend To The Left, 6.8ms
# image 149/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_230.png: 640x384 1 School, 1 Sharp Bend To The Left, 6.5ms
# image 150/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_250.png: 640x384 1 School, 1 Sharp Bend To The Left, 6.4ms
# image 151/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_260.png: 640x384 1 School, 1 Sharp Bend To The Left, 11.4ms
# image 152/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0060_270.png: 640x384 1 School, 1 Sharp Bend To The Left, 9.3ms
# image 153/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_170.png: 640x384 1 PEDESTRIAN CROSSING, 1 School, 7.0ms
# image 154/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_220.png: 640x384 1 School, 7.3ms
# image 155/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_230.png: 640x384 1 PEDESTRIAN CROSSING, 1 School, 6.6ms
# image 156/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_270.png: 640x384 1 PEDESTRIAN CROSSING, 6.4ms
# image 157/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_280.png: 640x384 1 PEDESTRIAN CROSSING, 6.6ms
# image 158/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_300.png: 640x384 1 PEDESTRIAN CROSSING, 1 School, 7.1ms
# image 159/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_310.png: 640x384 1 PEDESTRIAN CROSSING, 6.5ms
# image 160/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_330.png: 640x384 1 PEDESTRIAN CROSSING, 6.4ms
# image 161/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_350.png: 640x384 1 PEDESTRIAN CROSSING, 6.4ms
# image 162/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_370.png: 640x384 1 PEDESTRIAN CROSSING, 6.8ms
# image 163/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0068_380.png: 640x384 1 PEDESTRIAN CROSSING, 1 School, 7.2ms
# image 164/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_10.png: 640x384 1 PEDESTRIAN CROSSING, 6.5ms
# image 165/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_190.png: 640x384 1 PEDESTRIAN CROSSING, 7.0ms
# image 166/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_20.png: 640x384 1 PEDESTRIAN CROSSING, 7.0ms
# image 167/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_200.png: 640x384 1 PEDESTRIAN CROSSING, 7.3ms
# image 168/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_210.png: 640x384 1 PEDESTRIAN CROSSING, 6.9ms
# image 169/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_250.png: 640x384 1 PEDESTRIAN CROSSING, 6.7ms
# image 170/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_270.png: 640x384 1 PEDESTRIAN CROSSING, 6.8ms
# image 171/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_290.png: 640x384 1 PEDESTRIAN CROSSING, 9.0ms
# image 172/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_310.png: 640x384 1 PEDESTRIAN CROSSING, 6.9ms
# image 173/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_320.png: 640x384 1 PEDESTRIAN CROSSING, 6.7ms
# image 174/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_360.png: 640x384 1 PEDESTRIAN CROSSING, 6.8ms
# image 175/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_370.png: 640x384 1 PEDESTRIAN CROSSING, 6.6ms
# image 176/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_380.png: 640x384 1 PEDESTRIAN CROSSING, 7.1ms
# image 177/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_390.png: 640x384 1 PEDESTRIAN CROSSING, 7.1ms
# image 178/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_40.png: 640x384 1 PEDESTRIAN CROSSING, 8.9ms
# image 179/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_410.png: 640x384 1 PEDESTRIAN CROSSING, 6.6ms
# image 180/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_430.png: 640x384 1 PEDESTRIAN CROSSING, 6.8ms
# image 181/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_440.png: 640x384 1 PEDESTRIAN CROSSING, 6.8ms
# image 182/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_450.png: 640x384 1 PEDESTRIAN CROSSING, 6.8ms
# image 183/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_460.png: 640x384 1 PEDESTRIAN CROSSING, 6.6ms
# image 184/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_470.png: 640x384 1 PEDESTRIAN CROSSING, 7.4ms
# image 185/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_480.png: 640x384 1 PEDESTRIAN CROSSING, 7.2ms
# image 186/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_490.png: 640x384 1 PEDESTRIAN CROSSING, 6.7ms
# image 187/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_50.png: 640x384 1 School, 6.8ms
# image 188/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_500.png: 640x384 1 PEDESTRIAN CROSSING, 7.3ms
# image 189/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_520.png: 640x384 1 PEDESTRIAN CROSSING, 7.4ms
# image 190/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_540.png: 640x384 1 PEDESTRIAN CROSSING, 6.7ms
# image 191/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_550.png: 640x384 1 PEDESTRIAN CROSSING, 6.6ms
# image 192/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_560.png: 640x384 1 PEDESTRIAN CROSSING, 6.4ms
# image 193/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_570.png: 640x384 1 PEDESTRIAN CROSSING, 11.0ms
# image 194/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_580.png: 640x384 1 PEDESTRIAN CROSSING, 6.7ms
# image 195/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_600.png: 640x384 1 PEDESTRIAN CROSSING, 7.4ms
# image 196/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_630.png: 640x384 1 PEDESTRIAN CROSSING, 6.9ms
# image 197/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_640.png: 640x384 1 PEDESTRIAN CROSSING, 6.7ms
# image 198/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_650.png: 640x384 1 PEDESTRIAN CROSSING, 6.5ms
# image 199/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0069_680.png: 640x384 1 PEDESTRIAN CROSSING, 6.7ms
# image 200/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_120.png: 640x384 1 School, 1 Side Road Right, 6.5ms
# image 201/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_130.png: 640x384 1 Side Road Right, 6.9ms
# image 202/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_140.png: 640x384 1 School, 12.5ms
# image 203/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_150.png: 640x384 1 PEDESTRIAN CROSSING, 1 School, 7.1ms
# image 204/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_160.png: 640x384 1 PEDESTRIAN CROSSING, 11.2ms
# image 205/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_180.png: 640x384 1 School, 6.8ms
# image 206/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_210.png: 640x384 1 School, 8.7ms
# image 207/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_220.png: 640x384 1 PEDESTRIAN CROSSING, 1 School, 8.1ms
# image 208/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_250.png: 640x384 1 PEDESTRIAN CROSSING, 11.2ms
# image 209/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_260.png: 640x384 1 PEDESTRIAN CROSSING, 9.4ms
# image 210/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_280.png: 640x384 1 PEDESTRIAN CROSSING, 14.4ms
# image 211/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0071_290.png: 640x384 1 PEDESTRIAN CROSSING, 8.4ms
# image 212/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_220.png: 640x384 1 Side Road Right, 8.9ms
# image 213/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_230.png: 640x384 1 Side Road Right, 8.6ms
# image 214/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_240.png: 640x384 1 Side Road Right, 9.3ms
# image 215/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_250.png: 640x384 1 Side Road Right, 9.7ms
# image 216/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_270.png: 640x384 1 Side Road Right, 1 Crossroads, 8.1ms
# image 217/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_280.png: 640x384 1 Crossroads, 10.6ms
# image 218/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_290.png: 640x384 1 Side Road Right, 8.1ms
# image 219/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_300.png: 640x384 1 Side Road Right, 8.4ms
# image 220/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_350.png: 640x384 1 Crossroads, 10.6ms
# image 221/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_380.png: 640x384 1 Side Road Right, 1 Crossroads, 9.7ms
# image 222/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_400.png: 640x384 1 Sharp Bend To The Left, 1 Crossroads, 9.4ms
# image 223/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_410.png: 640x384 1 Sharp Bend To The Left, 14.9ms
# image 224/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0072_420.png: 640x384 (no detections), 9.6ms
# image 225/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_0.png: 384x640 1 PEDESTRIAN CROSSING, 10.5ms
# image 226/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_100.png: 384x640 1 Side Road Left, 10.9ms
# image 227/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_110.png: 384x640 (no detections), 10.5ms
# image 228/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_120.png: 384x640 (no detections), 9.6ms
# image 229/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_130.png: 384x640 1 Sharp Bend To The Left, 15.1ms
# image 230/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_140.png: 384x640 1 Crossroads, 11.2ms
# image 231/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_150.png: 384x640 1 Side Road Left, 1 Crossroads, 11.0ms
# image 232/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_170.png: 384x640 1 Side Road Left, 11.7ms
# image 233/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_20.png: 384x640 (no detections), 13.9ms
# image 234/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_30.png: 384x640 1 Side Road Left, 13.5ms
# image 235/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_40.png: 384x640 (no detections), 12.4ms
# image 236/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_50.png: 384x640 1 PEDESTRIAN CROSSING, 11.7ms
# image 237/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_60.png: 384x640 1 Side Road Right, 12.5ms
# image 238/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_70.png: 384x640 (no detections), 11.5ms
# image 239/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_80.png: 384x640 1 Side Road Right, 1 Crossroads, 9.5ms
# image 240/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0075_90.png: 384x640 (no detections), 6.9ms
# image 241/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0077_0.png: 384x640 1 PEDESTRIAN CROSSING, 6.9ms
# image 242/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0077_10.png: 384x640 1 PEDESTRIAN CROSSING, 7.0ms
# image 243/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0077_20.png: 384x640 1 PEDESTRIAN CROSSING, 8.7ms
# image 244/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0077_30.png: 384x640 1 PEDESTRIAN CROSSING, 7.2ms
# image 245/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0077_40.png: 384x640 1 PEDESTRIAN CROSSING, 6.6ms
# image 246/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0078_370.png: 384x640 (no detections), 6.4ms
# image 247/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0078_380.png: 384x640 1 Crossroads, 6.6ms
# image 248/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0078_390.png: 384x640 1 Road Hump, 1 Crossroads, 6.5ms
# image 249/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_0.png: 384x640 2 PEDESTRIAN CROSSINGs, 6.6ms
# image 250/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_20.png: 384x640 2 PEDESTRIAN CROSSINGs, 7.1ms
# image 251/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_40.png: 384x640 1 PEDESTRIAN CROSSING, 6.8ms
# image 252/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_50.png: 384x640 1 PEDESTRIAN CROSSING, 6.7ms
# image 253/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_580.png: 384x640 (no detections), 6.6ms
# image 254/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_590.png: 384x640 1 no use of horn, 7.7ms
# image 255/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_60.png: 384x640 1 PEDESTRIAN CROSSING, 7.1ms
# image 256/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_600.png: 384x640 1 no use of horn, 8.5ms
# image 257/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_610.png: 384x640 (no detections), 9.2ms
# image 258/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_620.png: 384x640 (no detections), 6.8ms
# image 259/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_640.png: 384x640 (no detections), 6.5ms
# image 260/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_650.png: 384x640 (no detections), 6.9ms
# image 261/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_660.png: 384x640 (no detections), 6.9ms
# image 262/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_670.png: 384x640 1 no use of horn, 6.9ms
# image 263/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_680.png: 384x640 1 no use of horn, 6.5ms
# image 264/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_690.png: 384x640 1 no use of horn, 8.7ms
# image 265/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0079_70.png: 384x640 1 PEDESTRIAN CROSSING, 7.3ms
# image 266/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V
662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_300.png: 384x640 1 Side Road Right, 1 Crossroads, 6.9ms
# image 352/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_320.png: 384x640 1 Side Road Left, 13.8ms
# image 353/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_340.png: 384x640 1 Side Road Left, 1 Crossroads, 6.6ms
# image 354/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_360.png: 384x640 1 Side Road Left, 1 Crossroads, 6.8ms
# image 355/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_380.png: 384x640 1 Side Road Left, 1 Side Road Right, 1 Crossroads, 6.4ms
# image 356/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_400.png: 384x640 1 Side Road Left, 1 Crossroads, 6.5ms
# image 357/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_420.png: 384x640 2 Side Road Lefts, 1 Crossroads, 8.7ms
# image 358/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_440.png: 384x640 (no detections), 9.3ms
# image 359/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_50.png: 384x640 1 Side Road Left, 7.0ms
# image 360/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_70.png: 384x640 1 Side Road Left, 7.1ms
# image 361/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0103_90.png: 384x640 1 Side Road Left, 6.7ms
# image 362/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4330.png: 384x640 1 PEDESTRIAN CROSSING, 6.9ms
# image 363/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4640.png: 384x640 1 U Turn, 6.8ms
# image 364/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4650.png: 384x640 1 U Turn, 6.6ms
# image 365/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4670.png: 384x640 1 Sharp Bend To The Left, 1 U Turn, 6.5ms
# image 366/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4700.png: 384x640 1 Sharp Bend To The Left, 6.4ms
# image 367/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4710.png: 384x640 (no detections), 8.1ms
# image 368/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4720.png: 384x640 (no detections), 7.9ms
# image 369/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4730.png: 384x640 1 PEDESTRIAN CROSSING, 1 Side Road Left, 8.5ms
# image 370/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4740.png: 384x640 1 PEDESTRIAN CROSSING, 12.7ms
# image 371/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4760.png: 384x640 1 PEDESTRIAN CROSSING, 6.6ms
# image 372/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4780.png: 384x640 1 PEDESTRIAN CROSSING, 6.6ms
# image 373/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4800.png: 384x640 1 PEDESTRIAN CROSSING, 6.7ms
# image 374/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0107_4820.png: 384x640 1 PEDESTRIAN CROSSING, 8.6ms
# image 375/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_10.png: 384x640 1 Side Road Left, 6.6ms
# image 376/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_20.png: 384x640 1 Side Road Left, 6.9ms
# image 377/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_30.png: 384x640 1 Side Road Left, 6.5ms
# image 378/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_40.png: 384x640 1 Side Road Left, 9.5ms
# image 379/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_490.png: 384x640 (no detections), 7.8ms
# image 380/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_50.png: 384x640 1 Side Road Left, 7.3ms
# image 381/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_510.png: 384x640 (no detections), 6.9ms
# image 382/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_550.png: 384x640 (no detections), 6.7ms
# image 383/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_560.png: 384x640 1 PEDESTRIAN CROSSING, 7.6ms
# image 384/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_580.png: 384x640 1 Road Hump, 6.9ms
# image 385/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_590.png: 384x640 (no detections), 9.8ms
# image 386/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_60.png: 384x640 1 PEDESTRIAN CROSSING, 1 Side Road Left, 7.0ms
# image 387/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_600.png: 384x640 (no detections), 12.5ms
# image 388/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0111_610.png: 384x640 1 Sharp Bend To The Right, 6.8ms
# ...
# image 534/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0167_13490.png: 384x640 1 Road Hump, 6.6ms
# image 535/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0167_5940.png: 384x640 (no detections), 7.5ms
# image 536/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0167_5950.png: 384x640 1 Road Hump, 6.7ms
# image 537/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0167_5960.png: 384x640 1 speed limit 40 km/h, 1 Sharp Bend To The Right, 6.6ms
# image 538/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V
662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_45660.png: 384x640 1 No Overtaking, 6.8ms
# image 628/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_45670.png: 384x640 1 No Overtaking, 6.7ms
# image 629/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_45680.png: 384x640 1 No Overtaking, 6.8ms
# image 630/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_47520.png: 384x640 1 No Overtaking, 7.4ms
# image 631/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_47530.png: 384x640 1 speed limit 80 km/h, 6.8ms
# image 632/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_47540.png: 384x640 1 No Overtaking, 7.3ms
# image 633/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_47550.png: 384x640 1 No Overtaking, 6.8ms
# image 634/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_47560.png: 384x640 (no detections), 6.8ms
# image 635/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_4820.png: 384x640 (no detections), 7.4ms
# image 636/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_48260.png: 384x640 1 speed limit 80 km/h, 7.0ms
# image 637/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_48270.png: 384x640 1 speed limit 80 km/h, 6.8ms
# image 638/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_48280.png: 384x640 1 speed limit 80 km/h, 6.8ms
# image 639/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_4830.png: 384x640 1 Sharp Bend To The Right, 7.1ms
# image 640/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_4840.png: 384x640 1 No Overtaking, 6.7ms
# image 641/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_4850.png: 384x640 1 No Overtaking, 2 Sharp Bend To The Rights, 12.8ms
# image 642/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_4860.png: 384x640 2 Sharp Bend To The Rights, 7.7ms
# image 643/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_4870.png: 384x640 2 Sharp Bend To The Rights, 6.6ms
# image 644/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_49090.png: 384x640 1 No Overtaking, 1 Sharp Bend To The Left, 6.8ms
# image 645/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_49100.png: 384x640 1 No Overtaking, 1 Sharp Bend To The Left, 6.7ms
# image 646/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_49110.png: 384x640 1 No Overtaking, 1 Sharp Bend To The Left, 6.7ms
# image 647/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_49750.png: 384x640 (no detections), 12.9ms
# image 648/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_49760.png: 384x640 1 speed limit 80 km/h, 11.8ms
# image 649/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_49770.png: 384x640 (no detections), 9.3ms
# image 650/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_49780.png: 384x640 1 speed limit 80 km/h, 8.7ms
# image 651/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9590.png: 384x640 (no detections), 11.7ms
# image 652/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9600.png: 384x640 1 PEDESTRIAN CROSSING, 9.1ms
# image 653/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9610.png: 384x640 (no detections), 12.3ms
# image 654/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9620.png: 384x640 (no detections), 8.3ms
# image 655/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9630.png: 384x640 1 Sharp Bend To The Left, 9.2ms
# image 656/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9640.png: 384x640 1 Sharp Bend To The Left, 12.6ms
# image 657/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9650.png: 384x640 1 Sharp Bend To The Left, 1 Sharp Bend To The Right, 9.9ms
# image 658/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9660.png: 384x640 1 Sharp Bend To The Left, 1 Sharp Bend To The Right, 10.0ms
# image 659/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9670.png: 384x640 1 Sharp Bend To The Left, 10.9ms
# image 660/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9680.png: 384x640 1 Sharp Bend To The Left, 1 Sharp Bend To The Right, 9.9ms
# image 661/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9690.png: 384x640 1 Side Road Left, 1 Sharp Bend To The Left, 10.0ms
# image 662/662 /content/drive/MyDrive/Dataset- -Conference/test/images/V0181_9700.png: 384x640 1 Side Road Left, 1 Sharp Bend To The Left, 1 Sharp Bend To The Right, 11.2ms
# Speed: 2.2ms preprocess, 8.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Define paths
import shutil
source_folder = '/content/runs'
destination_folder = '/content/drive/MyDrive/Dataset- -Conference/yolov8/test_final'  # Path to the destination folder
# Copy the folder and its contents to the destination
shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/drive/MyDrive/Dataset- -Conference/yolov8/test_final'
